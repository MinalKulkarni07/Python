# %% [markdown]
# ### Advance Billing System

# %%
# -- User input section
#Enter Product 1 -
#Samosa
#Do you Want to add more [Y/N]
# Y
# Enter Product 2 -
# Kachori
# Do you Want to add more [Y/N]
# Y
# Enter Product 3 -
# Fafda
# Do you Want to add more [Y/N]
# Y
# Enter Product 4 -
# Jalebi
# Do you Want to add more [Y/N]
# N
# Enter Samosa Price :
# 300/-
# Enter Kachori Price :
# 100/-
# Enter Fafda Price :
# 100/-
# Enter Jalebi Price :
# 200/-

# Do You Want to add GST [Y/N]
# [note : if user select `N` Print bill without GST]
# [Note User select yes `Y`]
# Enter GST % = 18
# -------Out put -------

# 1. Samosa = 300/-
# 2. Kachori = 100/-
# 3. Fafda = 100/-
# 4. Jalebi = 200/-
# -------------------
# Total = 700
# GST = 18%
# -------------------
# Final Total = 826/-
# -------------------

# %%
# Advance Billing System
data_dict = {}

count = 1
while True:
    Product = input(f"Enter Product {count}")
    data_dict[Product] = 0
    Add_Product = input("Do you want to add more product[Y/N]: ")
    if Add_Product == "Y":
        count += 1
    elif Add_Product == "N":
        break 

for Product in data_dict.keys():
    while True:
        Price = input(f"Enter {Product} Price: ")
        Price = int(Price)
        data_dict[Product] = Price
        break
          
def total(Prices):
    return sum(Prices)

def gst(Total, gst_percentage):
    return Total * (gst_percentage / 100)

def final_total(Total, GST):
    return (Total + GST)
    
Add_GST = input("Do you want to add GST [Y/N]")
GST = 0
if Add_GST == "Y":
    gst_percentage = int(input("Enter GST percentage :"))
    Total = total(data_dict.values())
    GST = round(gst(Total, gst_percentage),2)
    print(f"GST = {gst_percentage}%")
    print(f"GST = {GST}")

          
print("\n------Bill------")
count = 1
for Product, Price in data_dict.items():
    print(f"{count}. {Product} = {Price}/-")
    count+= 1
    
print("--------------")
Total = total(data_dict.values())
print("Total = ",Total)

if Add_GST == "Y":
    print(f"GST = {gst_percentage}%")
else:
    print(f"GST = 0")
    
print("--------------")
Final_Total = final_total(Total, GST)
print(f"Final Total = {int(Final_Total)}/-")
print("--------------")
# Out:
# Enter Product 1 Samosa
# Do you want to add more product[Y/N]:  Y
# Enter Product 2 Kachori
# Do you want to add more product[Y/N]:  Y
# Enter Product 3 Fafda
# Do you want to add more product[Y/N]:  Y
# Enter Product 4 Jalebi
# Do you want to add more product[Y/N]:  N
# Enter Samosa Price:  300
# Enter Kachori Price:  100
# Enter Fafda Price:  100
# Enter Jalebi Price:  200
# Do you want to add GST [Y/N] Y
# Enter GST percentage : 18
# GST = 18%
# GST = 126.0
#
# ------Bill------
# 1. Samosa = 300/-
# 2. Kachori = 100/-
# 3. Fafda = 100/-
# 4. Jalebi = 200/-
# --------------
# Total =  700
# GST = 18%
# --------------
# Final Total = 826/-
# --------------
